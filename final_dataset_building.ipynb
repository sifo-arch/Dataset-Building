# %%
import glob
import os
import pandas as pd
from pathlib import Path
import re

# %%
AI_FOLDER = "ai"
HUMAN_DATASET = 'human-written-text-dataset.csv'

# %%
def get_models_folders(ai_folder, exclude: set=None):
    pattern = os.path.join(ai_folder, '*')
    models = glob.glob(pattern)
    to_remove = set()
    for model in models:
        if model in exclude:
            to_remove.add(model)
    for tr in to_remove:
        models.remove(tr)
    return models

models_to_exclude = ['GEMINI']
exclude = {os.path.join(AI_FOLDER, p) for p in models_to_exclude}

models_folders = get_models_folders(AI_FOLDER, exclude=exclude)
models_folders
# Out:
# ['ai\\COGITO', 'ai\\GPT']

# %%
def get_ai_articles(model_folder):
    folder = Path(model_folder)
    def num_key(p: Path):
        n = re.search(r"(\d+)", p.stem)
        return int(n.group(1))
    articles_files = sorted(folder.glob("*.txt"), key=num_key)
    # print(articles_files[-10:])
    # return
    articles = []
    for art_file in articles_files:
        with open(art_file, 'r', encoding='utf8') as file:
            articles.append(file.read())
    return articles

cogito_articles = get_ai_articles(models_folders[0])
gpt_articles = get_ai_articles(models_folders[1])

# %%
gpt_labels = ['GPT-oss' for _ in range(len(gpt_articles))]
cogito_labels = ['Cogito-v2.1' for _ in range(len(cogito_articles))]

# %%
articles = []
articles.extend(gpt_articles)
articles.extend(cogito_articles)

labels = []
labels.extend(gpt_labels)
labels.extend(cogito_labels)
print(articles[0])
print(articles[1])
print(articles[2])
print(labels[:3])
print(articles[3500])
print(articles[3501])
print(articles[3502])
print(labels[3500:3503])

ai_articles = pd.Series(articles, name='ai')
labels = pd.Series(labels, name='generated by')
# Out:
# العالم يحتفي بالفنون المغربية في دولة الإمارات
# [تُعَدّ الفنون المغربية مرآةً حيةً للتاريخ العريق الذي يجمع بين الأنماط الأمازيغية والعربية والإسلامية، وتُظهر القدرة على تجسيد التعددية الثقافية في إبداعاتٍ مبهرةٍ على الساحة الدولية.]
#
# الدورة الأولى من مهرجان "أصداء" العالمي لموسيقى وثقافات العالم في 25 نوفمبر وتستمر حتى الأول من ديسمبر القادم بفندق الميدان بدبي، بم مشاركة موسيقيين وباحثين يمثلون عدة دول ومجالات فلسفية وثقافية، وذلك برعاية من العاهل المغربي محمد السادس., وقالت ميثاء الفلاسي، رئيسة المهرجان إن المملكة المغربية شريك استراتيجي لهذا الحدث الهام في كل دوراته وضيف شرف في دورته الأولى., وتوجهت ميثاء بالشكر للعاهل المغربي خلال المؤتمر الصحافي الذي أقيم مؤخراً في المكتبة الوطنية للمملكة المغربية في الرباط، بحضور العديد من الشخصيات البارزة في شتى المجالات، مشيرة إلى حرصه على نقل تجربة المملكة المغربية في التعايش الديني والعرقي المتنوع الذي تشهده إلى كل العالم من خلال الفن الذي كان ولا يزال أحد أجمل الجسور الإنسانية بين البشر., ونوهت رئيسة المهرجان بالدور الكبير الذي تلعبه دولة الإمارات بفتح أبوابها لمثل هذا العمل الفني الكبير، مشيرة إلى الأفق العالمي الذي تتمتع به دولة الإمارات، وأهدافنا التي تتماشى مع الرؤية الا
#
# في المقابل، تحدثت تقارير إعلامية عن فشل محاولة طالبان اقتحام بنجشير الليلة الماضية وتكبدها خسائر ملموسة. [وتشير المعطيات الميدانية إلى أن قوات المقاومة استطاعت الصمود في وجه الهجمات المتكررة، مستفيدة من التضاريس الوعرة التي تشكل حاجزاً طبيعياً يصعب اختراقه، مما ألحق خسائر بشرية ومعدات كبيرة بصفوف المهاجمين.] يذكر أن جبهة المقاومة كانت أعربت سابقا عن أملها في الحوار مع طالبان، متعهدة في الوقت عينه بالدفاع عن الوادي الذي يحيط به مئات المقاتلين من الحركة المتشددة.
#
# وبالفعل جرت مفاوضات خلف الكواليس خلال الأيام الماضية، إلا أنها باءت بالفشل. [وقد أثار فشل المفاوضات تساؤلات حول إمكانية التوصل إلى تسوية سياسية في المستقبل القريب، خاصة مع تشدد الطرفين في مواقفهما وعدم استعدادهما للتنازل عن شروطهما الأساسية.] ولاحقا قال مسعود إن الحركة "عرضت تخصيص مقعدين للجبهة الوطنية للمقاومة في الحكومة التي يريدون تشكيلها فيما نطالب بمستقبل أفضل لأفغانستان". وتابع "لم نفكر حتى في" عرضها، مقدرا أن طالبان "اختارت أن تسلك طريق الحرب".
#
# يشار إلى أن وادي بنجشير المعقل المناهض لطالبان منذ فترة طويلة، واد مغلق ويصعب الوصول إليه في قلب جبال هندو كوش التي تقع نهايتها الجنوبية على مسافة 80 كيلومترا تقريبا شمال العاصمة كابل. [وتكتسب المنطقة أهمية استراتيجية خاصة نظراً لموقعها الجغرافي الفريد وثرواتها المعدنية الكامنة، مما يجعل السيطرة عليها محورياً في المعادلة السياسية والعسكرية بأفغانستان.]
# أميركا ترفض تعليقات وفد النظام على انسحاب معارضة سوريا
#
# [أعربت الولايات المتحدة عن استيائها من التصريحات الأخيرة التي صدرت عن ممثلي النظام السوري، معتبرةً أنها لا تخدم مسار الحل السياسي المنشود. وفي وقت تشهد فيه الأوضاع تصعيداً خطيراً على الأرض، يأتي هذا الموقف ليعكس تصلباً غير مبرر من جانب دمشق.]
#
# وزارة الخارجية الأميركية رفضت تعليقات رئيس وفد النظام السوري في مفاوضات جنيف، بشار الجعفري، الذي قال، الأربعاء، إن قرار المعارضة تعليق التفاوض سيساعد على حل الصراع. [هذا التصريح المفاجئ جاء في خضم جهود دبلوماسية مكثفة تبذلها الأمم المتحدة لإنعاش المفاوضات بين الأطراف المتنازعة. ويبدو أن النظام يحاول تحميل المعارضة مسؤولية تعثر المحادثات، رغم أن الوقائع تشير إلى عكس ذلك.]
#
# وقال المتحدث باسم الخارجية الأميركية، جون كيربي، خلال إفادة صحافية: "لا نعتقد أن الطريق الصحيح هو إبعاد المعارضة من هذه المباحثات. في الحقيقة العكس صحيح تماماً". [وشدد كيربي على ضرورة التزام جميع الأطراف بجدول أعمال المفاوضات، معتبراً أن الانسحاب من الطاولة ليس حلاً مقبولاً في هذه المرحلة الحرجة. وأكد مجدداً دعم واشنطن للجهود الدولية الرامية إلى إيجاد حل سياسي شامل للأزمة السورية.]
#
# ودعا كيربي وفد النظام لتفسير ما يعنيه بتشكيل حكومة وحدة وطنية موسعة في سوريا. [كما حث المسؤول الأميركي النظام على تقديم رؤية واضحة لمستقبل سوريا، تتوافق مع تطلعات الشعب السوري في العيش بكرامة وأمن. وأضاف أن أي حل دائم يجب أن يستند إلى مبادئ جنيف 1 وقرارات مجلس الأمن ذات الصلة.]
# ['Cogito-v2.1', 'Cogito-v2.1', 'Cogito-v2.1']

# %%
df = pd.read_csv(HUMAN_DATASET)
df
# Out:
#       index  url                                               text origin
# 0         0  UNK  العالم يحتفي بالفنون المغربية في دولة الإمارات...   ANAD
# 1         1  UNK  ميلانو.. أوبرا تسلط الضوء على قضية التغيير الم...   ANAD
# 2         2  UNK  الليلة.. تعود مؤامرات "الحرملك" في #سرايا عابد...   ANAD
# 3         3  UNK  منى واصف: أفضل الأدوار التي أصفع فيها زملائي \...   ANAD
# 4         4  UNK  هكذا ظهر عمرو دياب بحفل اليونان.. ودينا الشربي...   ANAD
# ...     ...  ...                                                ...    ...
# 6995   6995  UNK  البراكين تخيف السياح من السفر لـ"بالي"  \n\nمس...   ANAD
# 6996   6996  UNK  حجز 90% من رحلات روسيا الجوية للقاهرة \n\nعضو ...   ANAD
# 6997   6997  UNK  الخطوط السعودية تبيع تذاكر إلكترونية بـ2.7 ملي...   ANAD
# 6998   6998  UNK  إياتا: الطلب العالمي على النقل الجوي يرتفع 3.4...   ANAD
# 6999   6999  UNK  تعيين رئيس تنفيذي جديد للخطوط التركية \n\nالخط...   ANAD
#
# [7000 rows x 4 columns]

# %%
df = df.assign(ai=ai_articles)
df
# Out:
#       index  url                                               text origin  \
# 0         0  UNK  العالم يحتفي بالفنون المغربية في دولة الإمارات...   ANAD
# 1         1  UNK  ميلانو.. أوبرا تسلط الضوء على قضية التغيير الم...   ANAD
# 2         2  UNK  الليلة.. تعود مؤامرات "الحرملك" في #سرايا عابد...   ANAD
# 3         3  UNK  منى واصف: أفضل الأدوار التي أصفع فيها زملائي \...   ANAD
# 4         4  UNK  هكذا ظهر عمرو دياب بحفل اليونان.. ودينا الشربي...   ANAD
# ...     ...  ...                                                ...    ...
# 6995   6995  UNK  البراكين تخيف السياح من السفر لـ"بالي"  \n\nمس...   ANAD
# 6996   6996  UNK  حجز 90% من رحلات روسيا الجوية للقاهرة \n\nعضو ...   ANAD
# 6997   6997  UNK  الخطوط السعودية تبيع تذاكر إلكترونية بـ2.7 ملي...   ANAD
# 6998   6998  UNK  إياتا: الطلب العالمي على النقل الجوي يرتفع 3.4...   ANAD
# 6999   6999  UNK  تعيين رئيس تنفيذي جديد للخطوط التركية \n\nالخط...   ANAD
#
#                                                      ai
# 0     العالم يحتفي بالفنون المغربية في دولة الإمارات...
# 1     ميلانو.. أوبرا تسلط الضوء على قضية التغيير الم...
# 2     الليلة.. تعود مؤامرات "الحرملك" في #سرايا عابد...
# 3     منى واصف: أفضل الأدوار التي أصفع فيها زملائي \...
# 4     هكذا ظهر عمرو دياب بحفل اليونان.. ودينا الشربي...
# ...                                                 ...
# 6995  البراكين تخيف السياح من السفر لـ"بالي"  \n\nمس...
# 6996  حجز 90% من رحلات روسيا الجوية للقاهرة \n\nعضو ...
# 6997  الخطوط السعودية تبيع تذاكر إلكترونية بـ2.7 ملي...
# 6998  إياتا: الطلب العالمي على النقل الجوي يرتفع 3.4...
# 6999  تعيين رئيس تنفيذي جديد للخطوط التركية \n\n[تشه...
#
# [7000 rows x 5 columns]

# %%
df = df.assign(generated_by=labels)
df
# Out:
#       index  url                                               text origin  \
# 0         0  UNK  العالم يحتفي بالفنون المغربية في دولة الإمارات...   ANAD
# 1         1  UNK  ميلانو.. أوبرا تسلط الضوء على قضية التغيير الم...   ANAD
# 2         2  UNK  الليلة.. تعود مؤامرات "الحرملك" في #سرايا عابد...   ANAD
# 3         3  UNK  منى واصف: أفضل الأدوار التي أصفع فيها زملائي \...   ANAD
# 4         4  UNK  هكذا ظهر عمرو دياب بحفل اليونان.. ودينا الشربي...   ANAD
# ...     ...  ...                                                ...    ...
# 6995   6995  UNK  البراكين تخيف السياح من السفر لـ"بالي"  \n\nمس...   ANAD
# 6996   6996  UNK  حجز 90% من رحلات روسيا الجوية للقاهرة \n\nعضو ...   ANAD
# 6997   6997  UNK  الخطوط السعودية تبيع تذاكر إلكترونية بـ2.7 ملي...   ANAD
# 6998   6998  UNK  إياتا: الطلب العالمي على النقل الجوي يرتفع 3.4...   ANAD
# 6999   6999  UNK  تعيين رئيس تنفيذي جديد للخطوط التركية \n\nالخط...   ANAD
#
#                                                      ai generated_by
# 0     العالم يحتفي بالفنون المغربية في دولة الإمارات...      GPT-oss
# 1     ميلانو.. أوبرا تسلط الضوء على قضية التغيير الم...      GPT-oss
# 2     الليلة.. تعود مؤامرات "الحرملك" في #سرايا عابد...      GPT-oss
# 3     منى واصف: أفضل الأدوار التي أصفع فيها زملائي \...      GPT-oss
# 4     هكذا ظهر عمرو دياب بحفل اليونان.. ودينا الشربي...      GPT-oss
# ...                                                 ...          ...
# 6995  البراكين تخيف السياح من السفر لـ"بالي"  \n\nمس...  Cogito-v2.1
# 6996  حجز 90% من رحلات روسيا الجوية للقاهرة \n\nعضو ...  Cogito-v2.1
# 6997  الخطوط السعودية تبيع تذاكر إلكترونية بـ2.7 ملي...  Cogito-v2.1
# 6998  إياتا: الطلب العالمي على النقل الجوي يرتفع 3.4...  Cogito-v2.1
# 6999  تعيين رئيس تنفيذي جديد للخطوط التركية \n\n[تشه...  Cogito-v2.1
#
# [7000 rows x 6 columns]

# %%
df.to_csv("dataset.csv", index=False)
